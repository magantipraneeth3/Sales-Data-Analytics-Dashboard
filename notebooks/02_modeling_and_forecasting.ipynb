# %% [markdown]
# # Sales Modeling & Forecasting
# Train an order-level Random Forest model and a monthly recursive Random Forest forecast.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.data_cleaning import clean_sales_data
clean_sales_data()

# %%
from models.sales_prediction import train
model, metrics = train()
metrics

# %%
from src.forecasting import train_forecast
forecast, mae, rmse = train_forecast(6)
forecast.tail(10)

# %%
import matplotlib.pyplot as plt
actual = forecast[forecast.Type == 'Actual']
future = forecast[forecast.Type == 'Forecast']
plt.figure(figsize=(12,5))
plt.plot(actual.Date, actual.Revenue, marker='o', label='Actual')
plt.plot(future.Date, future.Revenue, marker='o', linestyle='--', label='Forecast')
plt.title('Monthly Revenue Forecast')
plt.ylabel('Revenue')
plt.legend()
plt.grid(alpha=.2)
plt.show()

# %% [markdown]
# ## Model interpretation
# Use MAE and RMSE for forecast error and R² for order-level regression quality. Forecast values are constrained to non-negative revenue because sales revenue cannot be negative.
